# %%
from scidownl import scihub_download
import pandas as pd

# %%
## series of scraping apis to maximise number of pds obtained
## scihub: https://pypi.org/project/scidownl/
## pubmed: https://github.com/billgreenwald/Pubmed-Batch-Download
##### other: https://github.com/NLPatVCU/PaperScraper, https://pypi.org/project/paperscraper/ -> seems to duplicate functions of pubmed scraper

# %%
all_abstracts = pd.read_csv('data/included_abstracts_17032022.csv', index_col = 0)

# %%
len(all_abstracts)
# Out:
# 38828

# %%
all_abstracts.head()
# Out:
#        pmid                               doi  \
# 0  35174749     10.1080/03007995.2022.2043658
# 1  35180095         10.1109/JBHI.2022.3152625
# 2  35177120        10.1186/s40249-022-00946-4
# 3  35180083        10.1109/TBCAS.2022.3152623
# 4  35179731  10.5137/1019-5149.JTN.35996-21.1
#
#                                                title  \
# 0  Rationale and design of the Brazilian Diabetes...
# 1  Automatic Representative Frame Selection and I...
# 2  Comparing different machine learning technique...
# 3  An Energy Efficient ECG Ventricular Ectopic Be...
# 4  An early warning system using machine learning...
#
#                                             abstract  \
# 0  Optimal control of traditional risk factors on...
# 1  Endobronchial ultrasound (EBUS) elastography v...
# 2  Coronavirus disease 2019 (COVID-19) is still o...
# 3  Wearable Artificial Intelligence-of-Things (AI...
# 4  Early warning systems (EWS) that can flag impo...
#
#                 article_date                pubmed_date     article_type lang  \
# 0  2022-02-17 00:00:00+00:00  2022-02-18 00:00:00+00:00  Journal Article  eng
# 1  2022-02-18 00:00:00+00:00  2022-02-19 00:00:00+00:00  Journal Article  eng
# 2  2022-02-17 00:00:00+00:00  2022-02-19 00:00:00+00:00  Journal Article  eng
# 3  2022-02-18 00:00:00+00:00  2022-02-19 00:00:00+00:00  Journal Article  eng
# 4  2021-09-21 00:00:00+00:00  2022-02-19 00:00:00+00:00  Journal Article  eng
#
#                                              journal  \
# 0               Current medical research and opinion
# 1  IEEE journal of biomedical and health informatics
# 2                     Infectious diseases of poverty
# 3  IEEE transactions on biomedical circuits and s...
# 4                               Turkish neurosurgery
#
#                      journal_short  ... affil_countries  \
# 0                Curr Med Res Opin  ...             NaN
# 1      IEEE J Biomed Health Inform  ...             NaN
# 2               Infect Dis Poverty  ...             NaN
# 3  IEEE Trans Biomed Circuits Syst  ...             NaN
# 4                   Turk Neurosurg  ...             NaN
#
#   affil_countries_unique affil_first_country affil_last_country  \
# 0                    NaN                 NaN                NaN
# 1                    NaN                 NaN                NaN
# 2                    NaN                 NaN                NaN
# 3                    NaN                 NaN                NaN
# 4                    NaN                 NaN                NaN
#
#   affil_fill_country countries_lc  lmic_author_flag  lmic_author_lower_flag  \
# 0            England          NaN               0.0                     0.0
# 1      United States          NaN               0.0                     0.0
# 2            England          NaN               0.0                     0.0
# 3      United States          NaN               0.0                     0.0
# 4             Turkey          NaN               0.0                     0.0
#
#    lmic_china_flag    year
# 0              0.0  2022.0
# 1              0.0  2022.0
# 2              0.0  2022.0
# 3              0.0  2022.0
# 4              0.0  2022.0
#
# [5 rows x 84 columns]

# %%
#create dict to allow easy swap between using pmid or doi

id_dict = dict(zip(all_abstracts['pmid'], all_abstracts['doi']))

# %% [markdown]
# ## get list of pmids or dois

# %%
pmid_list = all_abstracts['pmid'].tolist()
doi_list = all_abstracts['doi'].tolist()

# %%
#test_list = doi_list[5100:5100]
test_list = pmid_list[5100:5110]

# %% [markdown]
# ## source pubmed

# %%
# need to convert the list to a string for input into pubmed script
pmid_string =  ','.join([str(item) for item in test_list])
print(pmid_string)
# Out:
# 34903773,34950928,34976794,32307321,34083090,32432557,32348266,34100770,34057419,32527593

# %%
## args -pmids [single comma separated string of pmids]; -pmf [tsv file with column of pmids, and column for file names],
## -out [output directory, defaulted fetched_pdfs]; -errors [output file for failed pmids, default unfetched_pmids.tsv],
## -v [--verbose]
##if found -> ./fetched_pdfs
##if not found -> write to unfetched_pmids.tsv

# !python fetch_pubmed.py -pmids $pmid_string -v
# Out:
# Trying to fetch pmid 34903773
# ** Reprint #34903773 already downloaded and in folder; skipping.
# Trying to fetch pmid 34950928
# Trying genericCitationLabelled
# Trying pubmed_central_v2
# Trying acsPublications
# Trying uchicagoPress
# Trying nejm
# Trying futureMedicine
# Trying science_direct
# ** fetching of reprint 34950928 failed from error Invalid URL 'pERtdG92FnkdkJflgkf8Y9f55S1nSC7sJjx9yRINPEuuqE0uFN6Cf27i5tNcBFWL': No scheme supplied. Perhaps you meant http://pERtdG92FnkdkJflgkf8Y9f55S1nSC7sJjx9yRINPEuuqE0uFN6Cf27i5tNcBFWL?
# Trying to fetch pmid 34976794
# Trying genericCitationLabelled
# Trying pubmed_central_v2
# Trying acsPublications
# Trying uchicagoPress
# Trying nejm
# Trying futureMedicine
# Trying science_direct
# ** fetching of reprint 34976794 failed from error Invalid URL 'false': No scheme supplied. Perhaps you meant http://false?
# Trying to fetch pmid 32307321
# Trying genericCitationLabelled
# Trying pubmed_central_v2
# Trying acsPublications
# Trying uchicagoPress
# Trying nejm
# Trying futureMedicine
# Trying science_direct
# Trying direct_pdf_link
# ** Reprint 32307321 could not be fetched with the current finders.
# Trying to fetch pmid 34083090
# Trying genericCitationLabelled
# Trying pubmed_central_v2
# Trying acsPublications
# Trying uchicagoPress
# Trying nejm
# Trying futureMedicine
# Trying science_direct
# Trying direct_pdf_link
# ** Reprint 34083090 could not be fetched with the current finders.
# Trying to fetch pmid 32432557
# Trying genericCitationLabelled
# Trying pubmed_central_v2
# ** fetching reprint using the 'pubmed central' finder...
# ** fetching of reprint 32432557 succeeded
# Trying to fetch pmid 32348266
# Trying genericCitationLabelled
# Trying pubmed_central_v2
# ** fetching reprint using the 'pubmed central' finder...
# ** fetching of reprint 32348266 succeeded
# Trying to fetch pmid 34100770
# Trying genericCitationLabelled
# Trying pubmed_central_v2
# ** fetching reprint using the 'pubmed central' finder...
# ** fetching of reprint 34100770 succeeded
# Trying to fetch pmid 34057419
# Trying genericCitationLabelled
# Trying pubmed_central_v2
# ** fetching reprint using the 'pubmed central' finder...
# ** fetching of reprint 34057419 succeeded
# Trying to fetch pmid 32527593
# Trying genericCitationLabelled
# Trying pubmed_central_v2
# Trying acsPublications
# Trying uchicagoPress
# Trying nejm
# Trying futureMedicine
# Trying science_direct
# ** fetching reprint using the 'science_direct' finder...
# ** fetching of reprint 32527593 failed from error list index out of range

# %% [markdown]
# ## source: scihub

# %%
unfetched = pd.read_table('unfetched_pmids.tsv', header=None)

unfetched['doi'] = unfetched[0].map(id_dict)

# %%
sci_list = unfetched['doi'].tolist()

# %%
sci_list
# Out:
# ['10.3389/fdgth.2021.732049',
#  '10.3389/fonc.2021.737368',
#  '10.1016/j.jfma.2020.03.024',
#  '10.1016/j.jfma.2021.05.010',
#  '10.1016/j.ultrasmedbio.2020.03.017']

# %%
def download_multi_papers(source):
    for x in source:
        scihub_download(x, paper_type="doi", out="./fetched_pdfs/")

# %%
download_multi_papers(sci_list)
# Out:
# [INFO] | 2022/03/18 13:18:53 | Choose scihub url [0]: https://sci-hub.st
# [INFO] | 2022/03/18 13:18:58 | <- Request: scihub_url=https://sci-hub.st, source=DoiSource[type=doi, id=10.3389/fdgth.2021.732049]
# [INFO] | 2022/03/18 13:18:58 | -> Response: status_code=200, content_length=24
# [WARNING] | 2022/03/18 13:18:58 | Error occurs, task status: extracting_failed, error: No pdf tag was found in the given content with the selector: #pdf
# [INFO] | 2022/03/18 13:18:58 | Choose scihub url [1]: https://sci-hub.se
# [INFO] | 2022/03/18 13:18:58 | <- Request: scihub_url=https://sci-hub.se, source=DoiSource[type=doi, id=10.3389/fdgth.2021.732049]
# [INFO] | 2022/03/18 13:18:58 | -> Response: status_code=403, content_length=8065
# [WARNING] | 2022/03/18 13:18:58 | Error occurs, task status: crawling_failed, error: Error occurs when crawling source: DoiSource[type=doi, id=10.3389/fdgth.2021.732049]
# [INFO] | 2022/03/18 13:18:58 | Choose scihub url [2]: https://sci-hub.ru
# [INFO] | 2022/03/18 13:18:58 | <- Request: scihub_url=https://sci-hub.ru, source=DoiSource[type=doi, id=10.3389/fdgth.2021.732049]
# [INFO] | 2022/03/18 13:18:58 | -> Response: status_code=403, content_length=8065
# [WARNING] | 2022/03/18 13:18:58 | Error occurs, task status: crawling_failed, error: Error occurs when crawling source: DoiSource[type=doi, id=10.3389/fdgth.2021.732049]
# [INFO] | 2022/03/18 13:18:58 | Choose scihub url [3]: http://sci-hub.st
# [INFO] | 2022/03/18 13:19:03 | <- Request: scihub_url=http://sci-hub.st, source=DoiSource[type=doi, id=10.3389/fdgth.2021.732049]
# [INFO] | 2022/03/18 13:19:03 | -> Response: status_code=200, content_length=24
# [WARNING] | 2022/03/18 13:19:03 | Error occurs, task status: extracting_failed, error: No pdf tag was found in the given content with the selector: #pdf
# [INFO] | 2022/03/18 13:19:03 | Choose scihub url [4]: http://sci-hub.se
# [INFO] | 2022/03/18 13:19:03 | <- Request: scihub_url=http://sci-hub.se, source=DoiSource[type=doi, id=10.3389/fdgth.2021.732049]
# [INFO] | 2022/03/18 13:19:03 | -> Response: status_code=403, content_length=8065
# [WARNING] | 2022/03/18 13:19:03 | Error occurs, task status: crawling_failed, error: Error occurs when crawling source: DoiSource[type=doi, id=10.3389/fdgth.2021.732049]
# [INFO] | 2022/03/18 13:19:03 | Choose scihub url [5]: http://sci-hub.ru
# [INFO] | 2022/03/18 13:19:03 | <- Request: scihub_url=http://sci-hub.ru, source=DoiSource[type=doi, id=10.3389/fdgth.2021.732049]
# [INFO] | 2022/03/18 13:19:03 | -> Response: status_code=403, content_length=8065
# [WARNING] | 2022/03/18 13:19:03 | Error occurs, task status: crawling_failed, error: Error occurs when crawling source: DoiSource[type=doi, id=10.3389/fdgth.2021.732049]
# [ERROR] | 2022/03/18 13:19:03 | Failed to download the paper: 10.3389/fdgth.2021.732049. Please try again.
# [INFO] | 2022/03/18 13:19:03 | Choose scihub url [0]: https://sci-hub.st
# [INFO] | 2022/03/18 13:19:07 | <- Request: scihub_url=https://sci-hub.st, source=DoiSource[type=doi, id=10.3389/fonc.2021.737368]
# [INFO] | 2022/03/18 13:19:07 | -> Response: status_code=200, content_length=24
# [WARNING] | 2022/03/18 13:19:07 | Error occurs, task status: extracting_failed, error: No pdf tag was found in the given content with the selector: #pdf
# [INFO] | 2022/03/18 13:19:07 | Choose scihub url [1]: https://sci-hub.se
# [INFO] | 2022/03/18 13:19:07 | <- Request: scihub_url=https://sci-hub.se, source=DoiSource[type=doi, id=10.3389/fonc.2021.737368]
# [INFO] | 2022/03/18 13:19:07 | -> Response: status_code=403, content_length=8065
# [WARNING] | 2022/03/18 13:19:07 | Error occurs, task status: crawling_failed, error: Error occurs when crawling source: DoiSource[type=doi, id=10.3389/fonc.2021.737368]
# [INFO] | 2022/03/18 13:19:07 | Choose scihub url [2]: https://sci-hub.ru
# [INFO] | 2022/03/18 13:19:07 | <- Request: scihub_url=https://sci-hub.ru, source=DoiSource[type=doi, id=10.3389/fonc.2021.737368]
# [INFO] | 2022/03/18 13:19:07 | -> Response: status_code=403, content_length=8065
# [WARNING] | 2022/03/18 13:19:07 | Error occurs, task status: crawling_failed, error: Error occurs when crawling source: DoiSource[type=doi, id=10.3389/fonc.2021.737368]
# [INFO] | 2022/03/18 13:19:07 | Choose scihub url [3]: http://sci-hub.st
# [INFO] | 2022/03/18 13:19:12 | <- Request: scihub_url=http://sci-hub.st, source=DoiSource[type=doi, id=10.3389/fonc.2021.737368]
# [INFO] | 2022/03/18 13:19:12 | -> Response: status_code=200, content_length=24
# [WARNING] | 2022/03/18 13:19:12 | Error occurs, task status: extracting_failed, error: No pdf tag was found in the given content with the selector: #pdf
# [INFO] | 2022/03/18 13:19:12 | Choose scihub url [4]: http://sci-hub.se
# [INFO] | 2022/03/18 13:19:12 | <- Request: scihub_url=http://sci-hub.se, source=DoiSource[type=doi, id=10.3389/fonc.2021.737368]
# [INFO] | 2022/03/18 13:19:12 | -> Response: status_code=403, content_length=8065
# [WARNING] | 2022/03/18 13:19:12 | Error occurs, task status: crawling_failed, error: Error occurs when crawling source: DoiSource[type=doi, id=10.3389/fonc.2021.737368]
# [INFO] | 2022/03/18 13:19:12 | Choose scihub url [5]: http://sci-hub.ru
# [INFO] | 2022/03/18 13:19:12 | <- Request: scihub_url=http://sci-hub.ru, source=DoiSource[type=doi, id=10.3389/fonc.2021.737368]
# [INFO] | 2022/03/18 13:19:12 | -> Response: status_code=403, content_length=8065
# [WARNING] | 2022/03/18 13:19:12 | Error occurs, task status: crawling_failed, error: Error occurs when crawling source: DoiSource[type=doi, id=10.3389/fonc.2021.737368]
# [ERROR] | 2022/03/18 13:19:12 | Failed to download the paper: 10.3389/fonc.2021.737368. Please try again.
# [INFO] | 2022/03/18 13:19:12 | Choose scihub url [0]: https://sci-hub.st
# [INFO] | 2022/03/18 13:19:13 | <- Request: scihub_url=https://sci-hub.st, source=DoiSource[type=doi, id=10.1016/j.jfma.2020.03.024]
# [INFO] | 2022/03/18 13:19:13 | -> Response: status_code=200, content_length=19623
# [INFO] | 2022/03/18 13:19:13 | * Extracted information: {'url': 'https://sci-hub.st/downloads/2020-04-21/d4/10.1016@j.jfma.2020.03.024.pdf', 'title': 'Application of deep learning image assessment software VeriSee™ for diabetic retinopathy screening. Journal of the Formosan Medical Association'}
# [INFO] | 2022/03/18 13:19:13 | ↓ Successfully download the url to: ./fetched_pdfs\Application of deep learning image assessment software VeriSee™ for diabetic retinopathy screening. Journal of the Formosan Medical Association (1).pdf
# [INFO] | 2022/03/18 13:19:13 | Choose scihub url [0]: https://sci-hub.st
# 100% [............................................................................] 648459 / 648459
# [INFO] | 2022/03/18 13:19:13 | <- Request: scihub_url=https://sci-hub.st, source=DoiSource[type=doi, id=10.1016/j.jfma.2021.05.010]
# [INFO] | 2022/03/18 13:19:13 | -> Response: status_code=200, content_length=19658
# [INFO] | 2022/03/18 13:19:13 | * Extracted information: {'url': 'https://sci-hub.st/downloads/2021-05-25/3c/wang2021.pdf', 'title': 'Classification of community-acquired outbreaks for the global transmission of COVID-19  Machine learning and statistical model analysis. Journal of the Formosan Medical Association, 120, S26–S37'}
#  82% [.............................................................             ] 2326528 / 2818468
# [INFO] | 2022/03/18 13:19:14 | ↓ Successfully download the url to: ./fetched_pdfs\Classification of community-acquired outbreaks for the global transmission of COVID-19  Machine learning and statistical model analysis. Journal of the Formosan Medical Association, 120, S26–S37 (1).pdf
# [INFO] | 2022/03/18 13:19:14 | Choose scihub url [0]: https://sci-hub.st
# 100% [..........................................................................] 2818468 / 2818468
# [INFO] | 2022/03/18 13:19:14 | <- Request: scihub_url=https://sci-hub.st, source=DoiSource[type=doi, id=10.1016/j.ultrasmedbio.2020.03.017]
# [INFO] | 2022/03/18 13:19:14 | -> Response: status_code=200, content_length=19644
# [INFO] | 2022/03/18 13:19:14 | * Extracted information: {'url': 'https://sci-hub.st/downloads/2020-07-06/8e/horng2020.pdf', 'title': 'DeepNerve  A New Convolutional Neural Network for the Localization and Segmentation of the Median Nerve in Ultrasound Image Sequences. Ultrasound in Medicine & Biology'}
#  10% [........                                                                  ]  434176 / 4011574
# [INFO] | 2022/03/18 13:19:15 | ↓ Successfully download the url to: ./fetched_pdfs\DeepNerve  A New Convolutional Neural Network for the Localization and Segmentation of the Median Nerve in Ultrasound Image Sequences. Ultrasound in Medicine & Biology.pdf
# 100% [..........................................................................] 4011574 / 4011574
